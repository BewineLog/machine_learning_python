# %% [markdown]
# <a href="https://colab.research.google.com/github/programsec-bud/deep_learning_python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 = "Easy"
str4 = "%s python deep learning"%str1

# %%
print(str4)
# Out:
# Easy python deep learning

# %%
dict1 = {'name':'jay', 'age':20}
print(type(dict1))
print(dict1['name'],dict1['age'])
# Out:
# <class 'dict'>
# jay 20

# %%
dict1.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
dict1.values()
# Out:
# dict_values(['jay', 20])

# %%
dict1.items()
# Out:
# dict_items([('name', 'jay'), ('age', 20)])

# %%
try:
  print(data['address'])
except:
  print("not in dict")
finally:
  print('end')
# Out:
# not in dict
# end

# %%
# !git clone https://github.com/programsec-bud/deep_learning_python.git
# Out:
# Cloning into 'deep_learning_python'...
# ...

# %%
# !ls -ltr
# Out:
# total 8
# drwxr-xr-x 1 root root 4096 Jul  1 13:42 sample_data
# drwxr-xr-x 3 root root 4096 Jul 15 02:07 deep_learning_python

# %%
from google.colab import drive
drive.mount('/content/colab_drive')
# Out:
# Mounted at /content/colab_drive

# %%
# !ls -ltr
# Out:
# total 12
# drwxr-xr-x 1 root root 4096 Jul  1 13:42 sample_data
# drwxr-xr-x 3 root root 4096 Jul 15 02:07 deep_learning_python
# drwx------ 6 root root 4096 Jul 15 02:08 colab_drive

# %%
# !git clone https://github.com/programsec-bud/deep_learning_python.git /content/colab_drive
# Out:
# fatal: destination path '/content/colab_drive' already exists and is not an empty directory.
